# %% [markdown]
# # repositorio: https://github.com/platzi/platziData

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ## Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.14159
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'Javier'

# %% [markdown]
# ## Estructurados

# %%
from IPython.display import Image
Image('mysql_table_example.png')
#sueño de cualquier data engineer, se pueden manipular los datos fácilmente

# %% [markdown]
# ## Semi estructurados

# %%
Image('html_markup_example.png')
#hay mucha información pero no ordena

# %% [markdown]
# ## No estructurados
# no podemos aplicar métodos computacionales

# %% [markdown]
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than right now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Poster tipos de datos
# ## https://platzi.com/clases/1385-ingenieria-datos/22502-tipos-de-datos/

# %% [markdown]
# # Solicitudes  a la web

# %%
import requests

response = requests.get('https://platzi.com')
#response? -> nos da un docstring que nos da una descripción breve de lo que se hizo , es decir la documentación
#response?? -> nos muestra la clase, como está implementada la libreria, documentación
print(dir(response)) #-> nos va a dar todos los métodos que podemos utilizar con ese objeto

# %%
print(response.status_code) # nos da una respuesta del servidor 200 ok, 404 no se existe lo que se pide

# %%
print(response.headers)#diccionario de python,que nos muestra la cabecera de la petición, la cual contiene mucha información

# %%
print(response.headers['Date'])# acceder a los datos del diccionario

# %%
print(response.text)

# %% [markdown]
# # Extracción de información del HTML

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser') # se tiene que definir que es html, ya que también hay xml

print(soup.title.prettify())

# %%
soup.select('meta[name=description]') # metadatos de la página

# %%
soup.select('meta[name=description]')[0]['content'] # metadatos de la página

# %%
#análizar la estructura de la web

courses_links = soup.select('.HomeCategories-anchor') #class next to the href
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)

# %%
courses_links = soup.select('.CareerCourseItem-link')
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)

# %%
# el tiempo 

response2 = requests.get('https://www.eltiempo.com/')

soup2 = BeautifulSoup(response2.text, 'html.parser')

print(soup2.title)

# %%
news_links = soup2.select('.title-container a')

news = [new['href'] for new in news_links]

for new in news:
    print(new['h'])

# %%
new_broke = [new.split('/') for new in news]
news_title3 = []
news_title4 = []
for title in new_broke:
    if len(title) == 3:
        for i in title:
            news_title3.append(i)    
    elif len(title) == 4:
        for j in title:
            news_title4.append(j)

len(news_title4)
cont = 1
titles = []
print(news_title4)

# %% [markdown]
# # Series

# %%
import pandas as pd

series_test = pd.Series([100,200,300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
frame_test = pd.DataFrame({1999:[71, 38, 39],
                           2000:[34, 32, 32],
                           2001:[23, 39, 23]})
frame_test
# Out:
#    1999  2000  2001
# 0    71    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[71, 38, 39],
                           [34, 32, 32],
                           [23, 39, 23]], columns=(1999, 2000, 2001))
frame_test2
# Out:
#    1999  2000  2001
# 0    71    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# # Read Data

# %%
#pd.options.display.max_rows = 10

el_universal = pd.read_csv('web_scraper_curso_data_eng/eluniversal_2019_06_07_articles.csv',encoding='latin-1')

type(el_universal)
el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmÃ³ que...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niÃ±as y niÃ±os de l...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: AÃ­da Castro SÃ¡nchezDiseÃ±o web: Mig...
# 196  \nTingÃ¼indÃ­n, MichoacÃ¡n.- Diego Vidal Manzo...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# # Index and Section

# %%
# dictionary like

el_universal['title']#serie
# Out:
# 0      Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                    NaN
# 2                                                    NaN
# 3      Puebla: un tropiezo electoral no es una derrot...
# 4                              Entre faldas y pantalones
#                              ...
# 194    PolicÃ­a auxilia a hombre de la tercera edad q...
# 195    Las primeras reporteras que rompieron con los ...
# 196    Grupo armado ataca a subdirector de Seguridad ...
# 197                                                  NaN
# 198           Concacaf pide al Tri priorizar la Copa Oro
# Name: title, Length: 199, dtype: object

# %%
el_universal[['title','url']]#sub dataframe
# Out:
#                                                  title  \
# 0    Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# 4                            Entre faldas y pantalones
# ..                                                 ...
# 194  PolicÃ­a auxilia a hombre de la tercera edad q...
# 195  Las primeras reporteras que rompieron con los ...
# 196  Grupo armado ataca a subdirector de Seguridad ...
# 197                                                NaN
# 198         Concacaf pide al Tri priorizar la Copa Oro
#
#                                                    url
# 0    http://www.eluniversal.com.mx/metropoli/cdmx/m...
# 1           http://www.eluniversal.com.mx/deportes/box
# 2    https://www.tangible-eluniversal.com.mx/en-ver...
# 3    https://www.eluniversal.com.mx/articulo/maria-...
# ...

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10                                                NaN
# 11                                                NaN
# 12  El aÃ±o 2019 todavÃ­a es joven, pero un par de...
# 13                                                NaN
# 14  La banda de rock Los Amigos Invisibles se pres...
#
#                                                 title  \
# 10                                                NaN
# 11                                MarÃ­a Elena Morera
# 12                                                NaN
# 13                                       Andrew Selee
# 14  Los Amigos Invisibles en Naucalpan: Compra tus...
#
#                                                   url
# 10                             https://bit.ly/2jmdiXT
# 11  http://www.eluniversal.com.mx/autor-opinion/ar...
# 12  https://www.elgrafico.mx/espectaculos/ellas-so...
# 13  http://www.eluniversal.com.mx/autor-opinion/ar...
# ...

# %%
el_universal.iloc[66]['title']
# Out:
# 'NaasÃ³n â\x80\x9cha sido vÃ\xadctima de complot cibernÃ©ticoâ\x80\x9d, dice defensa'

# %%
el_universal.iloc[:5, 0]#primera columna  de 0-5
# Out:
# 0    \nLa procuradora Ernestina Godoy confirmÃ³ que...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niÃ±as y niÃ±os de l...
# Name: body, dtype: object

# %%
# formas recomendadas Label based

el_universal.loc[:, 'body':'title'] #traeme todo con body y title nada más, el último elemento es incluido
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmÃ³ que...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niÃ±as y niÃ±os de l...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: AÃ­da Castro SÃ¡nchezDiseÃ±o web: Mig...
# 196  \nTingÃ¼indÃ­n, MichoacÃ¡n.- Diego Vidal Manzo...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title
# 0    Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# # Data wrangling

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal.head()
# Out:
#                                                 body  \
# 0  \nLa procuradora Ernestina Godoy confirmÃ³ que...
# 1                                                NaN
# 2                                                NaN
# 3  \n\nTras el triunfo de Barbosa y la derrota de...
# 4  \n\nLa noticia de que las niÃ±as y niÃ±os de l...
#
#                                                title  \
# 0  Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                NaN
# 2                                                NaN
# 3  Puebla: un tropiezo electoral no es una derrot...
# 4                          Entre faldas y pantalones
#
#                                                  url newspaper_uid
# 0  http://www.eluniversal.com.mx/metropoli/cdmx/m...   eluniversal
# 1         http://www.eluniversal.com.mx/deportes/box   eluniversal
# 2  https://www.tangible-eluniversal.com.mx/en-ver...   eluniversal
# ...

# %%
# 2. Obetener el host
from urllib.parse import urlparse #parsear

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmÃ³ que...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niÃ±as y niÃ±os de l...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: AÃ­da Castro SÃ¡nchezDiseÃ±o web: Mig...
# 196  \nTingÃ¼indÃ­n, MichoacÃ¡n.- Diego Vidal Manzo...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de TlÃ¡huac; investigan vÃ­...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
el_universal['host'].value_counts() #contar datos
# Out:
# www.eluniversal.com.mx             115
# www.viveusa.mx                       9
# www.elbotiquin.mx                    9
# bit.ly                               8
# www.tangible-eluniversal.com.mx      7
# www.unionjalisco.mx                  6
# www.elgrafico.mx                     5
# oaxaca.eluniversal.com.mx            5
# www.eluniversalqueretaro.mx          5
# sanluis.eluniversal.com.mx           5
# www.eluniversalvideo.com.mx          4
# de10.com.mx                          4
# www.revistaclase.mx                  3
# www.unioncdmx.mx                     3
# www.unionpuebla.mx                   3
# www.clubeluniversal.mx               2
# www.facebook.com                     1
# www.unionedomex.mx                   1
# www.unionyucatan.mx                  1
# www.unionguanajuato.mx               1
# interactivo.eluniversal.com.mx       1
# twitter.com                          1
# Name: host, dtype: int64

# %% [markdown]
# # Missing Data

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

#str, puede ser cambiado por lo que necesitamos por ejemplo date(dt)
missing_titles = (el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_title>[^/]+)$')
                    .applymap(str)
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list)))
missing_titles
# Out:
#                                          missing_title
# 1                                                  box
# 2    en verdad padecio sifilis schubert el gran com...
# 6    ladron se dispara durante asalto pizzeria en m...
# 9    las bacterias que viven en tu celular y otros ...
# 10                                             2jmdiXT
# ..                                                 ...
# 182  10 famosos que lucen irreconocibles con unos k...
# 188                                      suscripciones
# 191                                            1TWQKcr
# 192             6 ejercicios para tonificar los brazos
# 197                                          seguridad
#
# [65 rows x 1 columns]

# %% [markdown]
# # Additional cleanup

# %%
# 4. añadir uid a las filas
import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())) , axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )
el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmÃ³ que...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niÃ±as y niÃ±os de l...
# ...                                                                             ...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 0b3554fa7bcb1999372a959a34bcab22  \nTexto: AÃ­da Castro SÃ¡nchezDiseÃ±o web: Mig...
# fef05cb73c5ba11f41aa58190726ca5a  \nTingÃ¼indÃ­n, MichoacÃ¡n.- Diego Vidal Manzo...
# ab3f9d29135096228449397395057c36                                                NaN
# ...

# %%
stripped_body = (el_universal
                    .apply(lambda row: row['body'], axis=1)
                    .astype(str)
                    .apply(lambda body: list(body))
                    .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                    .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmÃ³ que e...
# cb18691c58018e4163d72b0ed8bbcf38                                                  nan
# cf5bc6c8b4056dc4120a47d67699919e                                                  nan
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de CÃ¡...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niÃ±as y niÃ±os de la Ci...
#                                                           ...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: AÃ­da Castro SÃ¡nchezDiseÃ±o web: Migue...
# fef05cb73c5ba11f41aa58190726ca5a    TingÃ¼indÃ­n, MichoacÃ¡n.- Diego Vidal Manzo, ...
# ab3f9d29135096228449397395057c36                                                  nan
# dcdefeba6e4c6905af58a3b68f8bee94                                                  nan
# Length: 199, dtype: object

# %% [markdown]
# # Data enrichment

# %%
#5. tokenizar el titulo y el body
import nltk
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7ed61237edf5> in <module>
#       1 #5. tokenizar el titulo y el body
# ----> 2 import nltk
#       3 nltk.download()
#
# ModuleNotFoundError: No module named 'nltk'
